# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('auto-mpg.csv')

# %%
data.shape
# Out:
# (398, 9)

# %%
#displaying the features
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
#displaying top most 5 values
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#description before converting hp into float
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.size
# Out:
# 3582

# %%
#data types of all features
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
#displaying the count of each unique value in data
data["horsepower"].value_counts().head()
# Out:
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
# Name: horsepower, dtype: int64

# %%
#as hp contains values with "?" writing a contion to remove them
data = data[data["horsepower"] != '?']
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#here actually horsepower is a numeric and car is a string but it is showing it as object type
#Converting object to float and strings types
data["horsepower"] = data['horsepower'].astype(float)

# %%
data["car name"] = data["car name"].astype(str)

# %%
data.describe(include="all")
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model year      origin     car name
# count     392.000000  392.000000  392.000000          392
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 30.6+ KB

# %%
data.var()
# Out:
# C:\Users\ML Lab\AppData\Local\Temp\ipykernel_5736\445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# mpg                 60.918142
# cylinders            2.909696
# displacement     10950.367554
# horsepower        1481.569393
# weight          721484.709008
# acceleration         7.611331
# model year          13.569915
# origin               0.648860
# dtype: float64

# %%
data.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0  1985.0          14.5
# 1   NaN        NaN           NaN         NaN  2130.0           NaN
# 2   NaN        NaN           NaN         NaN     NaN           NaN
#
#    model year  origin        car name
# 0        73.0     1.0     amc matador
# 1         NaN     NaN      ford pinto
# 2         NaN     NaN  toyota corolla

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.plot(kind='scatter', x='cylinders', y='mpg', xlabel='cylinders', ylabel='mpg',
       title='Simple plot')
# Out:
# <AxesSubplot:title={'center':'Simple plot'}, xlabel='cylinders', ylabel='mpg'>

# %%
data["car name"].value_counts().head()
# Out:
# amc matador       5
# ford pinto        5
# toyota corolla    5
# toyota corona     4
# amc hornet        4
# Name: car name, dtype: int64

# %%
#finding correleation of each features
corr_mat = data.corr()
corr_mat
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# ...

# %%
#finding correleation of mpg attribute only
corr_mat["mpg"]
# Out:
# mpg             1.000000
# cylinders      -0.777618
# displacement   -0.805127
# horsepower     -0.778427
# weight         -0.832244
# acceleration    0.423329
# model year      0.580541
# origin          0.565209
# Name: mpg, dtype: float64

# %%
#corr values of mpg sorted in descinding order
corr_mat["mpg"].sort_values(ascending=False)
# Out:
# mpg             1.000000
# model year      0.580541
# origin          0.565209
# acceleration    0.423329
# cylinders      -0.777618
# horsepower     -0.778427
# displacement   -0.805127
# weight         -0.832244
# Name: mpg, dtype: float64

# %%
data['mpg'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
q1 = data["mpg"].quantile(0.25)
q2 = data["mpg"].quantile(0.50)
q3 = data["mpg"].quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print("Quartile 1:",q1)
print("Quartile 2:",q2)
print("Quartile 3:",q3)
print("IQR :",iqr)
print(lower_fence)
print(upper_fence)
# Out:
# Quartile 1: 17.0
# Quartile 2: 22.75
# Quartile 3: 29.0
# IQR : 12.0
# -1.0
# 47.0

# %%
data['cylinders'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
q1 = data["cylinders"].sort_values().quantile(0.25)
q3 = data["cylinders"].sort_values().quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print("Quartile 1:",q1)
print("Quartile 3:",q3)
print("IQR :",iqr)
print(lower_fence)
print(upper_fence)
# Out:
# Quartile 1: 4.0
# Quartile 3: 8.0
# IQR : 4.0
# -2.0
# 14.0

# %%
data['displacement'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
q1 = data["displacement"].sort_values().quantile(0.25)
q3 = data["displacement"].sort_values().quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print("Quartile 1:",q1)
print("Quartile 3:",q3)
print("IQR :",iqr)
print(lower_fence)
print(upper_fence)
# Out:
# Quartile 1: 105.0
# Quartile 3: 275.75
# IQR : 170.75
# -151.125
# 531.875

# %%
data['horsepower'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
q1 = data["horsepower"].sort_values().quantile(0.25)
q3 = data["horsepower"].sort_values().quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print("Quartile 1:",q1)
print("Quartile 3:",q3)
print("IQR :",iqr)
print(lower_fence)
print(upper_fence)
# Out:
# Quartile 1: 75.0
# Quartile 3: 126.0
# IQR : 51.0
# -1.5
# 202.5

# %%
data['acceleration'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
q1 = data["acceleration"].quantile(0.25)
q2 = data["acceleration"].quantile(0.50)
q3 = data["acceleration"].quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print("Quartile 1:",q1)
print("Quartile 2:",q2)
print("Quartile 3:",q3)
print("IQR :",iqr)
print(lower_fence)
print(upper_fence)
# Out:
# Quartile 1: 13.775
# Quartile 2: 15.5
# Quartile 3: 17.025
# IQR : 3.2499999999999982
# 8.900000000000002
# 21.899999999999995

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
              'acceleration', 'model year', 'origin', 'car name']
scatter_matrix(data[attributes],figsize=(30,30))
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='model year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='origin', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='model year', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='origin', ylabel='cylinders'>],
# ...

# %% [markdown]
# # We can detect outliers in two ways:
# 1.IQR Method
# 2.Z-score Method

# %% [markdown]
# # IQR Method

# %%
q1 = data["horsepower"].sort_values().quantile(0.25)
q3 = data["horsepower"].sort_values().quantile(0.50)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print(q1)
print(q3)
print(lower_fence)
print(upper_fence)
# Out:
# 75.0
# 93.5
# 47.25
# 121.25

# %%
data[(data["horsepower"] > lower_fence) & (data["horsepower"] < upper_fence)].shape
# Out:
# (288, 9)

# %%
data_no_outliers.shape
# Out:
# (288, 9)

# %% [markdown]
# # Removing outliers in accleration feature

# %%
q1 = data["acceleration"].quantile(0.25)
q3 = data["acceleration"].quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print(q1)
print(q3)
print(lower_fence)
print(upper_fence)
# Out:
# 13.775
# 17.025
# 8.900000000000002
# 21.899999999999995

# %%
data[(data["acceleration"] < lower_fence) & (data["acceleration"] > upper_fence)]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin, car name]
# Index: []

# %%
data['acceleration'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (392, 9)
